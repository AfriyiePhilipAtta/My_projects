# %%
#In this loaded raw data into DataFrame and transformed it

#importing pandas
import pandas as pd
df=pd.read_csv('/Users/User/Downloads/Data_analysis/Dataset.csv')
df
# Out:
#     transaction_date  customer_id store_location  zip_code  item_sku  \
# 0         2017-07-06     843290.0        Atlanta   54321.0  T5U9R3I7
# 1         2017-09-30     981477.0        Seattle   12345.0  B7H9N3M5
# 2         2017-07-09     233518.0        Seattle   12345.0  aB3C5dE7
# 3         2017-08-22     162835.0         Austin   54321.0  T2P5U9V1
# 4         2017-08-30     458901.0   Philadelphia   12345.0  W4Q7R2Z9
# ..               ...          ...            ...       ...       ...
# 994              NaN          NaN            NaN       NaN       NaN
# 995              NaN          NaN            NaN       NaN       NaN
# 996              NaN          NaN            NaN       NaN       NaN
# 997              NaN          NaN            NaN       NaN       NaN
# 998              NaN          NaN            NaN       NaN       NaN
#
#     item_category item_cost item_color shipped_to   taxes  ... Unnamed: 16  \
# ...

# %%
#checking for missing values

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_date  270 non-null    object
#  1   customer_id       270 non-null    float64
#  2   store_location    270 non-null    object
#  3   zip_code          270 non-null    float64
#  4   item_sku          270 non-null    object
#  5   item_category     270 non-null    object
#  6   item_cost         270 non-null    object
#  7   item_color        270 non-null    object
#  8   shipped_to        197 non-null    object
#  9   taxes             270 non-null    object
#  10  shipping          270 non-null    object
#  11  Unnamed: 11       0 non-null      float64
#  12  Unnamed: 12       0 non-null      float64
#  13  Unnamed: 13       0 non-null      float64
#  14  Unnamed: 14       0 non-null      float64
#  15  Unnamed: 15       0 non-null      float64
# ...

# %%
#Filling in missing value

# %%
df_null=df.fillna({'item_cost':0,'shipped_to':'Unknown'})
df_null
# Out:
#     transaction_date  customer_id store_location  zip_code  item_sku  \
# 0         2017-07-06     843290.0        Atlanta   54321.0  T5U9R3I7
# 1         2017-09-30     981477.0        Seattle   12345.0  B7H9N3M5
# 2         2017-07-09     233518.0        Seattle   12345.0  aB3C5dE7
# 3         2017-08-22     162835.0         Austin   54321.0  T2P5U9V1
# 4         2017-08-30     458901.0   Philadelphia   12345.0  W4Q7R2Z9
# ..               ...          ...            ...       ...       ...
# 994              NaN          NaN            NaN       NaN       NaN
# 995              NaN          NaN            NaN       NaN       NaN
# 996              NaN          NaN            NaN       NaN       NaN
# 997              NaN          NaN            NaN       NaN       NaN
# 998              NaN          NaN            NaN       NaN       NaN
#
#     item_category item_cost item_color shipped_to   taxes  ... Unnamed: 16  \
# ...

# %%
#Removing index
df_index=df_null.drop(index=266)
df_index
# Out:
#     transaction_date  customer_id store_location  zip_code  item_sku  \
# 0         2017-07-06     843290.0        Atlanta   54321.0  T5U9R3I7
# 1         2017-09-30     981477.0        Seattle   12345.0  B7H9N3M5
# 2         2017-07-09     233518.0        Seattle   12345.0  aB3C5dE7
# 3         2017-08-22     162835.0         Austin   54321.0  T2P5U9V1
# 4         2017-08-30     458901.0   Philadelphia   12345.0  W4Q7R2Z9
# ..               ...          ...            ...       ...       ...
# 994              NaN          NaN            NaN       NaN       NaN
# 995              NaN          NaN            NaN       NaN       NaN
# 996              NaN          NaN            NaN       NaN       NaN
# 997              NaN          NaN            NaN       NaN       NaN
# 998              NaN          NaN            NaN       NaN       NaN
#
#     item_category item_cost item_color shipped_to   taxes  ... Unnamed: 16  \
# ...

# %%
#removing duplicates
df_dup=df_index[df_index.duplicated(subset='customer_id',keep='last')]
df_dup
# Out:
#     transaction_date  customer_id store_location  zip_code  item_sku  \
# 0         2017-07-06     843290.0        Atlanta   54321.0  T5U9R3I7
# 1         2017-09-30     981477.0        Seattle   12345.0  B7H9N3M5
# 2         2017-07-09     233518.0        Seattle   12345.0  aB3C5dE7
# 3         2017-08-22     162835.0         Austin   54321.0  T2P5U9V1
# 4         2017-08-30     458901.0   Philadelphia   12345.0  W4Q7R2Z9
# ..               ...          ...            ...       ...       ...
# 993              NaN          NaN            NaN       NaN       NaN
# 994              NaN          NaN            NaN       NaN       NaN
# 995              NaN          NaN            NaN       NaN       NaN
# 996              NaN          NaN            NaN       NaN       NaN
# 997              NaN          NaN            NaN       NaN       NaN
#
#     item_category item_cost item_color shipped_to   taxes  ... Unnamed: 16  \
# ...

# %%
#Colunm of interest
col_interest=df_dup.drop(columns=['zip_code','item_sku'])
col_interest
# Out:
#     transaction_date  customer_id store_location item_category item_cost  \
# 0         2017-07-06     843290.0        Atlanta       Blouses    $39.99
# 1         2017-09-30     981477.0        Seattle     Outerwear    $39.99
# 2         2017-07-09     233518.0        Seattle         Pants    $59.99
# 3         2017-08-22     162835.0         Austin         Jeans   $129.99
# 4         2017-08-30     458901.0   Philadelphia         Jeans   $129.99
# ..               ...          ...            ...           ...       ...
# 993              NaN          NaN            NaN           NaN         0
# 994              NaN          NaN            NaN           NaN         0
# 995              NaN          NaN            NaN           NaN         0
# 996              NaN          NaN            NaN           NaN         0
# 997              NaN          NaN            NaN           NaN         0
#
#     item_color shipped_to   taxes shipping  Unnamed: 11  ...  Unnamed: 16  \
# ...

# %%
#Exploration with Pandas

# %%
import pandas as pd
df=pd.read_csv('/Users/User/Downloads/Data_analysis/Iris.csv')
df
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('/Users/User/Downloads/Data_analysis/Iris.csv')
#       3 df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Statistics ( find the Mean,Standard deviation, median ect.)
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Finding them individualy 
#For SepalLengthCm
#Mean
df_mean=f.SepalLengthCm.mean()
# Out:
# 5.843333333333334

# %%
#Median
df.SepalLengthCm.median()
# Out:
# 5.8

# %%
#Standard deviation
df.SepalLengthCm.std()
# Out:
# 0.8280661279778629

# %%
#Count
df.SepalLengthCm.count()
# Out:
# 150

# %%
#Using a single code for mean
df.drop(columns='Species')
#This code can be applied to all the statistical statements
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
#Finding Min and Max
#Max
df.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
#Min
df.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
#Finding percentiles
#For 20%
df.SepalLengthCm.quantile(0.20)
# Out:
# 5.0

# %%
#For 50%
df.SepalLengthCm.quantile(0.50)
# Out:
# 5.8
