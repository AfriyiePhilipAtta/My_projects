# %%
# In this lab Iuse pandas to create and Dataframe and matplotlib to visualize student performance



import pandas as pd
df=pd.read_csv('/Users/User/Downloads/Data_analysis/Student_performance_data _.csv')
df
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
col_interest.describe()
# Out:
#          StudentID          Age  ParentalEducation  StudyTimeWeekly  \
# count  2392.000000  2392.000000        2392.000000      2392.000000
# mean   2196.500000    16.468645           1.746237         9.771992
# std     690.655244     1.123798           1.000411         5.652774
# min    1001.000000    15.000000           0.000000         0.001057
# 25%    1598.750000    15.000000           1.000000         5.043079
# 50%    2196.500000    16.000000           2.000000         9.705363
# 75%    2794.250000    17.000000           2.000000        14.408410
# max    3392.000000    18.000000           4.000000        19.978094
#
#           Absences  ParentalSupport          GPA   GradeClass
# count  2392.000000      2392.000000  2392.000000  2392.000000
# mean     14.541388         2.122074     1.906186     2.983696
# std       8.467417         1.122813     0.915156     1.233908
# min       0.000000         0.000000     0.000000     0.000000
# ...

# %%
#For sinlgle column
col_interest['Age'].plot(kind='box',vert=False)
# Out:
# <Axes: >

# %%
#For Multiple Column
col_interest[['Age','StudyTimeWeekly','GPA','GradeClass']].plot(kind='box',vert=False)
# Out:
# <Axes: >

# %%
#Using other methods for Box plot
col_interest.plot.box(column='Age',vert=False)
# Out:
# <Axes: >

# %%
col_interest.plot.box(column=['Age','StudyTimeWeekly','GPA','GradeClass'],vert=False)
# Out:
# <Axes: >

# %%
#For all columns
col_interest[['Age','StudyTimeWeekly','GPA','GradeClass']].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#For columns 
col_interest[['Age','StudyTimeWeekly','GPA','GradeClass']].plot.hist(alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#For single columns
col_interest['GPA'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
col_interest['Age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
#All in one cell/Grapgh
col_interest['Age'].plot.hist()
col_interest['GPA'].plot.hist()
col_interest['GradeClass'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
col_interest.plot.scatter(x='Age',y='GradeClass')
# Out:
# <Axes: xlabel='Age', ylabel='GradeClass'>

# %%
#For clarity
col_interest.plot.scatter(x='Age',y='GradeClass',alpha=0.25)
# Out:
# <Axes: xlabel='Age', ylabel='GradeClass'>

# %%
#Visualization of two columns on one axis
ax=col_interest.plot.scatter(x='Age',y='GPA', alpha=0.25, label='GPA')
ax=col_interest.plot.scatter(x='Age',y='GradeClass',label='GradeClass', color='red',ax=ax,)

# %%
#Assigning lables to the axi
ax=col_interest.plot.scatter(x='Age',y='GPA', alpha=0.25, label='GPA')
ax=col_interest.plot.scatter(x='Age',y='GradeClass',label='GradeClass', color='red',ax=ax,)
plt.ylabel('score')
plt.title('Age of students')
# Out:
# Text(0.5, 1.0, 'Age of students')

# %%
#Percentages
col_interest['Age_percent']=df.Age/df.GPA
col_interest['Age_percent']
# Out:
# 0         5.803641
# 1         5.915381
# 2       133.212253
# 3         8.275655
# 4        13.198131
#            ...
# 2387      5.209073
# 2388      5.184271
# 2389     14.006425
# 2390      8.872638
# 2391      7.476587
# Name: Age_percent, Length: 2392, dtype: float64

# %%
col_interest['Age_percent'].plot(kind='box',vert=False)
# Out:
# <Axes: >

# %%
col_interest.plot.scatter(x='GPA',y='Age_percent',alpha=0.25,color='green')
# Out:
# <Axes: xlabel='GPA', ylabel='Age_percent'>
